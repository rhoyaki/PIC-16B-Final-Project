# %% [markdown]
# ### Introduction

# %% [markdown]
# In a time where there are a menagerie of movies being produced and shown in theaters and many of them being box office “flops” despite the best efforts of marketing and publicity, we wish to analyze the possible reasons as to why certain movies do not perform well while others do. In essence, we wish to use a neural network to predict the financial performance of films using attributes/features such as who worked on the film (actors and directors), length of the film, genre, etc.

# %% [markdown]
# ### Importing

# %%
#import modules and libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import keras
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, regularizers, callbacks
import keras
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
# Out:
# 2024-06-05 10:07:57.493234: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# warning exception handling
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ### Data Scraping

# %%
#initialize empty dataframe
df = pd.DataFrame()

#fetch data for data scraping 
url = "https://www.boxofficemojo.com/chart/top_lifetime_gross/?area=XWW"
result = requests.get(url)
doc = BeautifulSoup(result.text, "html.parser")
movie_table = doc.find_all("table")

#extracts the title, lifetime gross, and year of each movie, and stores these in a list of dictionaries.
movie_data = []
for row in movie_table[0].find_all("tr")[1:]:  # Skip the header row
    cells = row.find_all("td")
    current_title = cells[1].text
    current_gross = cells[2].text[1:]
    current_year = cells[3].text
    
    
    movie_data.append({"Title" : current_title,
                       "Lifetime Gross" : current_gross,
                       "Year" : current_year,
                      }
                     )

#concats with main dataframe
temp = pd.DataFrame(movie_data)
df = pd.concat([temp, df])

#fetch from subsequent pages
for i in range(200,1000,200):
    url = "https://www.boxofficemojo.com/chart/top_lifetime_gross/?area=XWW&offset="+str(i)
    result = requests.get(url)
    doc = BeautifulSoup(result.text, "html.parser")
    movie_table = doc.find_all("table")
    movie_data = []
    for row in movie_table[0].find_all("tr")[1:]:  # Skip the header row
        cells = row.find_all("td")
        current_title = cells[1].text
        current_gross = cells[2].text[1:]
        current_year = cells[3].text


        movie_data.append({"Title" : current_title,
                           "Lifetime Gross" : current_gross,
                           "Year" : current_year,
                          }
                         )

    temp = pd.DataFrame(movie_data, index = [i for i in range(i,i+200,1)])
    df = pd.concat([temp, df])

#final dataframe
revenue_data = df

# %% [markdown]
# ### Import Kaggle Datasets

# %%
import opendatasets as od
import os
movie_industry = "https://www.kaggle.com/datasets/danielgrijalvas/movies/data"
imdb2000 = "https://www.kaggle.com/datasets/thegoanpanda/imdb-top-2000-movies"

od.download(movie_industry)
od.download(imdb2000)
# Out:
# Skipping, found downloaded files in "./movies" (use force=True to force download)
# Skipping, found downloaded files in "./imdb-top-2000-movies" (use force=True to force download)

# %%
#the urls
movies = './movies'
imdb = './imdb-top-2000-movies'

# %%
#read the data from the urls
movie_industry = pd.read_csv(os.path.join(movies, 'movies.csv'))
imdb2000 = pd.read_csv(os.path.join(imdb, 'IMDb Top 2000 Movies.csv'), encoding_errors = 'replace')

# %%
#preprocess each dataframe for merging
movie_industry["Title"] = movie_industry["name"]
movie_industry = movie_industry.drop(["name", "year"], axis = 1)

imdb2000["Title"] = imdb2000["Movie Name"]
imdb2000 = imdb2000.drop(["Movie Name", "Movie Rank", "Year of Release"], axis = 1)

# %%
#merge the dataset
kaggle_data = pd.merge(movie_industry, imdb2000, how = "outer", on = "Title")
df = pd.merge(revenue_data, kaggle_data, how = "inner", on = "Title")

# %% [markdown]
# ### Data Cleaning

# %%
#print dataframe
df
# Out:
#                      Title Lifetime Gross  Year rating      genre  \
# 0         Captain Phillips    218,791,811  2013  PG-13  Adventure
# 1      The Prince of Egypt    218,613,188  1998     PG  Animation
# 2             Jack Reacher    218,340,595  2012  PG-13     Action
# 3        Kingdom of Heaven    218,237,071  2005      R     Action
# 4                Smallfoot    218,015,531  2018     PG  Animation
# ...                    ...            ...   ...    ...        ...
# 1050        Monsters, Inc.    579,723,768  2001      G  Animation
# 1051        Monsters, Inc.    579,723,768  2001      G  Animation
# 1052   Night at the Museum    574,482,479  2006     PG  Adventure
# 1053  Fifty Shades of Grey    569,651,467  2015      R      Drama
# 1054    Kong: Skull Island    568,652,812  2017  PG-13     Action
#
#                                 released  score     votes  \
# 0       October 11, 2013 (United States)    7.8  432000.0
# 1      December 18, 1998 (United States)    7.1  122000.0
# 2      December 21, 2012 (United States)    7.0  317000.0
# 3            May 6, 2005 (United States)    7.2  272000.0
# 4     September 28, 2018 (United States)    6.6   36000.0
# ...                                  ...    ...       ...
# 1050    November 2, 2001 (United States)    8.1  838000.0
# 1051    November 2, 2001 (United States)    8.1  838000.0
# 1052   December 22, 2006 (United States)    6.4  323000.0
# 1053   February 13, 2015 (United States)    4.1  304000.0
# 1054      March 10, 2017 (United States)    6.6  293000.0
#
#                    director             writer            star  \
# 0           Paul Greengrass          Billy Ray       Tom Hanks
# 1            Brenda Chapman    Philip LaZebnik      Val Kilmer
# 2     Christopher McQuarrie          Lee Child      Tom Cruise
# 3              Ridley Scott    William Monahan   Orlando Bloom
# 4         Karey Kirkpatrick  Karey Kirkpatrick  Channing Tatum
# ...                     ...                ...             ...
# 1050            Pete Docter        Pete Docter   Billy Crystal
# 1051            Pete Docter        Pete Docter   Billy Crystal
# 1052             Shawn Levy  Robert Ben Garant     Ben Stiller
# 1053     Sam Taylor-Johnson       Kelly Marcel  Dakota Johnson
# 1054    Jordan Vogt-Roberts         Dan Gilroy  Tom Hiddleston
#
#              country       budget        gross                  company  \
# 0      United States   55000000.0  218791811.0  Scott Rudin Productions
# 1      United States   70000000.0  218613188.0     DreamWorks Animation
# 2      United States   60000000.0  218340595.0       Paramount Pictures
# 3     United Kingdom  130000000.0  218122627.0    Twentieth Century Fox
# 4      United States   80000000.0  214040103.0   Warner Animation Group
# ...              ...          ...          ...                      ...
# 1050   United States  115000000.0  579707738.0  Pixar Animation Studios
# 1051   United States  115000000.0  579707738.0  Pixar Animation Studios
# 1052   United States  110000000.0  574481229.0    Twentieth Century Fox
# 1053   United States   40000000.0  569651467.0           Focus Features
# 1054   United States  185000000.0  566652812.0             Warner Bros.
#
#       runtime  IMDB Rating
# 0       134.0          7.8
# 1        99.0          NaN
# 2       130.0          NaN
# 3       144.0          NaN
# 4        96.0          NaN
# ...       ...          ...
# 1050     92.0          8.1
# 1051     92.0          8.1
# 1052    108.0          NaN
# 1053    125.0          NaN
# 1054    118.0          NaN
#
# [1055 rows x 17 columns]

# %%
#identifies the duplicate titles
df[df["Title"].duplicated()]
# Out:
#                     Title Lifetime Gross  Year rating      genre  \
# 9     Million Dollar Baby    216,763,646  2004  PG-13      Drama
# 10    Million Dollar Baby    216,763,646  2004  PG-13      Drama
# 11    Million Dollar Baby    216,763,646  2004  PG-13      Drama
# 12    Million Dollar Baby    216,763,646  2004  PG-13      Drama
# 13    Million Dollar Baby    216,763,646  2004  PG-13      Drama
# ...                   ...            ...   ...    ...        ...
# 1047       Monsters, Inc.    579,723,768  2001      G  Animation
# 1048       Monsters, Inc.    579,723,768  2001      G  Animation
# 1049       Monsters, Inc.    579,723,768  2001      G  Animation
# 1050       Monsters, Inc.    579,723,768  2001      G  Animation
# 1051       Monsters, Inc.    579,723,768  2001      G  Animation
#
#                               released  score     votes        director  \
# 9     January 28, 2005 (United States)    8.1  650000.0  Clint Eastwood
# 10    January 28, 2005 (United States)    8.1  650000.0  Clint Eastwood
# 11    January 28, 2005 (United States)    8.1  650000.0  Clint Eastwood
# 12    January 28, 2005 (United States)    8.1  650000.0  Clint Eastwood
# 13    January 28, 2005 (United States)    8.1  650000.0  Clint Eastwood
# ...                                ...    ...       ...             ...
# 1047  November 2, 2001 (United States)    8.1  838000.0     Pete Docter
# 1048  November 2, 2001 (United States)    8.1  838000.0     Pete Docter
# 1049  November 2, 2001 (United States)    8.1  838000.0     Pete Docter
# 1050  November 2, 2001 (United States)    8.1  838000.0     Pete Docter
# 1051  November 2, 2001 (United States)    8.1  838000.0     Pete Docter
#
#            writer           star        country       budget        gross  \
# 9     Paul Haggis   Hilary Swank  United States   30000000.0  216763646.0
# 10    Paul Haggis   Hilary Swank  United States   30000000.0  216763646.0
# 11    Paul Haggis   Hilary Swank  United States   30000000.0  216763646.0
# 12    Paul Haggis   Hilary Swank  United States   30000000.0  216763646.0
# 13    Paul Haggis   Hilary Swank  United States   30000000.0  216763646.0
# ...           ...            ...            ...          ...          ...
# 1047  Pete Docter  Billy Crystal  United States  115000000.0  579707738.0
# 1048  Pete Docter  Billy Crystal  United States  115000000.0  579707738.0
# 1049  Pete Docter  Billy Crystal  United States  115000000.0  579707738.0
# 1050  Pete Docter  Billy Crystal  United States  115000000.0  579707738.0
# 1051  Pete Docter  Billy Crystal  United States  115000000.0  579707738.0
#
#                       company  runtime  IMDB Rating
# 9                Warner Bros.    132.0          8.1
# 10               Warner Bros.    132.0          8.1
# 11               Warner Bros.    132.0          8.1
# 12               Warner Bros.    132.0          8.1
# 13               Warner Bros.    132.0          8.1
# ...                       ...      ...          ...
# 1047  Pixar Animation Studios     92.0          8.1
# 1048  Pixar Animation Studios     92.0          8.1
# 1049  Pixar Animation Studios     92.0          8.1
# 1050  Pixar Animation Studios     92.0          8.1
# 1051  Pixar Animation Studios     92.0          8.1
#
# [217 rows x 17 columns]

# %%
#check how many unique movies there are
len(df["Title"].unique())
# Out:
# 838

# %%
#remove duplicate movies
unique_titles_df = df.drop_duplicates(subset="Title", keep="first")
unique_titles_df
# Out:
#                      Title Lifetime Gross  Year rating      genre  \
# 0         Captain Phillips    218,791,811  2013  PG-13  Adventure
# 1      The Prince of Egypt    218,613,188  1998     PG  Animation
# 2             Jack Reacher    218,340,595  2012  PG-13     Action
# 3        Kingdom of Heaven    218,237,071  2005      R     Action
# 4                Smallfoot    218,015,531  2018     PG  Animation
# ...                    ...            ...   ...    ...        ...
# 1041           I Am Legend    585,410,052  2007  PG-13     Action
# 1042        Monsters, Inc.    579,723,768  2001      G  Animation
# 1052   Night at the Museum    574,482,479  2006     PG  Adventure
# 1053  Fifty Shades of Grey    569,651,467  2015      R      Drama
# 1054    Kong: Skull Island    568,652,812  2017  PG-13     Action
#
#                                 released  score     votes  \
# 0       October 11, 2013 (United States)    7.8  432000.0
# 1      December 18, 1998 (United States)    7.1  122000.0
# 2      December 21, 2012 (United States)    7.0  317000.0
# 3            May 6, 2005 (United States)    7.2  272000.0
# 4     September 28, 2018 (United States)    6.6   36000.0
# ...                                  ...    ...       ...
# 1041   December 14, 2007 (United States)    7.2  704000.0
# 1042    November 2, 2001 (United States)    8.1  838000.0
# 1052   December 22, 2006 (United States)    6.4  323000.0
# 1053   February 13, 2015 (United States)    4.1  304000.0
# 1054      March 10, 2017 (United States)    6.6  293000.0
#
#                    director             writer            star  \
# 0           Paul Greengrass          Billy Ray       Tom Hanks
# 1            Brenda Chapman    Philip LaZebnik      Val Kilmer
# 2     Christopher McQuarrie          Lee Child      Tom Cruise
# 3              Ridley Scott    William Monahan   Orlando Bloom
# 4         Karey Kirkpatrick  Karey Kirkpatrick  Channing Tatum
# ...                     ...                ...             ...
# 1041       Francis Lawrence   Mark Protosevich      Will Smith
# 1042            Pete Docter        Pete Docter   Billy Crystal
# 1052             Shawn Levy  Robert Ben Garant     Ben Stiller
# 1053     Sam Taylor-Johnson       Kelly Marcel  Dakota Johnson
# 1054    Jordan Vogt-Roberts         Dan Gilroy  Tom Hiddleston
#
#              country       budget        gross                  company  \
# 0      United States   55000000.0  218791811.0  Scott Rudin Productions
# 1      United States   70000000.0  218613188.0     DreamWorks Animation
# 2      United States   60000000.0  218340595.0       Paramount Pictures
# 3     United Kingdom  130000000.0  218122627.0    Twentieth Century Fox
# 4      United States   80000000.0  214040103.0   Warner Animation Group
# ...              ...          ...          ...                      ...
# 1041   United States  150000000.0  585410052.0             Warner Bros.
# 1042   United States  115000000.0  579707738.0  Pixar Animation Studios
# 1052   United States  110000000.0  574481229.0    Twentieth Century Fox
# 1053   United States   40000000.0  569651467.0           Focus Features
# 1054   United States  185000000.0  566652812.0             Warner Bros.
#
#       runtime  IMDB Rating
# 0       134.0          7.8
# 1        99.0          NaN
# 2       130.0          NaN
# 3       144.0          NaN
# 4        96.0          NaN
# ...       ...          ...
# 1041    101.0          NaN
# 1042     92.0          8.1
# 1052    108.0          NaN
# 1053    125.0          NaN
# 1054    118.0          NaN
#
# [838 rows x 17 columns]

# %%
#Lifetime Gross should be float for data analysis
print(unique_titles_df.dtypes)
# Out:
# Title              object
# Lifetime Gross     object
# Year               object
# rating             object
# genre              object
# released           object
# score             float64
# votes             float64
# director           object
# writer             object
# star               object
# country            object
# budget            float64
# gross             float64
# company            object
# runtime           float64
# IMDB Rating       float64
# dtype: object

# %%
#removing commas from Lifetime Gross
unique_titles_df['Lifetime Gross'] = unique_titles_df['Lifetime Gross'].str.replace(',', '')
unique_titles_df.head()
# Out:
#                  Title Lifetime Gross  Year rating      genre  \
# 0     Captain Phillips      218791811  2013  PG-13  Adventure
# 1  The Prince of Egypt      218613188  1998     PG  Animation
# 2         Jack Reacher      218340595  2012  PG-13     Action
# 3    Kingdom of Heaven      218237071  2005      R     Action
# 4            Smallfoot      218015531  2018     PG  Animation
#
#                              released  score     votes               director  \
# 0    October 11, 2013 (United States)    7.8  432000.0        Paul Greengrass
# 1   December 18, 1998 (United States)    7.1  122000.0         Brenda Chapman
# 2   December 21, 2012 (United States)    7.0  317000.0  Christopher McQuarrie
# 3         May 6, 2005 (United States)    7.2  272000.0           Ridley Scott
# 4  September 28, 2018 (United States)    6.6   36000.0      Karey Kirkpatrick
#
#               writer            star         country       budget  \
# 0          Billy Ray       Tom Hanks   United States   55000000.0
# 1    Philip LaZebnik      Val Kilmer   United States   70000000.0
# 2          Lee Child      Tom Cruise   United States   60000000.0
# 3    William Monahan   Orlando Bloom  United Kingdom  130000000.0
# 4  Karey Kirkpatrick  Channing Tatum   United States   80000000.0
#
#          gross                  company  runtime  IMDB Rating
# 0  218791811.0  Scott Rudin Productions    134.0          7.8
# 1  218613188.0     DreamWorks Animation     99.0          NaN
# 2  218340595.0       Paramount Pictures    130.0          NaN
# 3  218122627.0    Twentieth Century Fox    144.0          NaN
# 4  214040103.0   Warner Animation Group     96.0          NaN

# %%
#converting lifetime gross, year into float
unique_titles_df['Lifetime Gross'] = unique_titles_df['Lifetime Gross'].astype(float)
unique_titles_df['Year'] = unique_titles_df['Year'].astype(float)
print(unique_titles_df.dtypes)
# Out:
# Title              object
# Lifetime Gross    float64
# Year              float64
# rating             object
# genre              object
# released           object
# score             float64
# votes             float64
# director           object
# writer             object
# star               object
# country            object
# budget            float64
# gross             float64
# company            object
# runtime           float64
# IMDB Rating       float64
# dtype: object

# %%
#check for null values
print(unique_titles_df.isnull().sum())
# Out:
# Title               0
# Lifetime Gross      0
# Year                0
# rating              9
# genre               7
# released            7
# score               7
# votes               7
# director            7
# writer              7
# star                7
# country             7
# budget             23
# gross               8
# company             7
# runtime             7
# IMDB Rating       745
# dtype: int64

# %%
# replace them with appropriate substitutions
unique_titles_df[['rating', 'genre', 'director', 'writer', 'star', 'country', 'company']] = unique_titles_df[['rating', 'genre', 'director', 'writer', 'star', 'country', 'company']].fillna('Unknown')
unique_titles_df[['score', 'votes', 'budget', 'gross', 'runtime', 'IMDB Rating']] = unique_titles_df[['score', 'votes', 'budget', 'gross', 'runtime', 'IMDB Rating']].fillna(0.0)

print(unique_titles_df.isnull().sum())
# Out:
# Title             0
# Lifetime Gross    0
# Year              0
# rating            0
# genre             0
# released          7
# score             0
# votes             0
# director          0
# writer            0
# star              0
# country           0
# budget            0
# gross             0
# company           0
# runtime           0
# IMDB Rating       0
# dtype: int64

# %%
#extract the month from 'released' column and remove null values
unique_titles_df['released']  = unique_titles_df['released'].str.replace(',', '')
unique_titles_df['Date'] = unique_titles_df['released'].str.split('(').str.get(0).str.strip()
unique_titles_df['Date'] = pd.to_datetime(unique_titles_df['Date'])
unique_titles_df['Month'] = unique_titles_df['Date'].dt.month
unique_titles_df['Month'] = unique_titles_df['Month'].fillna(0.0)
unique_titles_df = unique_titles_df.drop(columns=['released', 'Date'])
unique_titles_df
# Out:
#                      Title  Lifetime Gross    Year rating      genre  score  \
# 0         Captain Phillips     218791811.0  2013.0  PG-13  Adventure    7.8
# 1      The Prince of Egypt     218613188.0  1998.0     PG  Animation    7.1
# 2             Jack Reacher     218340595.0  2012.0  PG-13     Action    7.0
# 3        Kingdom of Heaven     218237071.0  2005.0      R     Action    7.2
# 4                Smallfoot     218015531.0  2018.0     PG  Animation    6.6
# ...                    ...             ...     ...    ...        ...    ...
# 1041           I Am Legend     585410052.0  2007.0  PG-13     Action    7.2
# 1042        Monsters, Inc.     579723768.0  2001.0      G  Animation    8.1
# 1052   Night at the Museum     574482479.0  2006.0     PG  Adventure    6.4
# 1053  Fifty Shades of Grey     569651467.0  2015.0      R      Drama    4.1
# 1054    Kong: Skull Island     568652812.0  2017.0  PG-13     Action    6.6
#
#          votes               director             writer            star  \
# 0     432000.0        Paul Greengrass          Billy Ray       Tom Hanks
# 1     122000.0         Brenda Chapman    Philip LaZebnik      Val Kilmer
# 2     317000.0  Christopher McQuarrie          Lee Child      Tom Cruise
# 3     272000.0           Ridley Scott    William Monahan   Orlando Bloom
# 4      36000.0      Karey Kirkpatrick  Karey Kirkpatrick  Channing Tatum
# ...        ...                    ...                ...             ...
# 1041  704000.0       Francis Lawrence   Mark Protosevich      Will Smith
# 1042  838000.0            Pete Docter        Pete Docter   Billy Crystal
# 1052  323000.0             Shawn Levy  Robert Ben Garant     Ben Stiller
# 1053  304000.0     Sam Taylor-Johnson       Kelly Marcel  Dakota Johnson
# 1054  293000.0    Jordan Vogt-Roberts         Dan Gilroy  Tom Hiddleston
#
#              country       budget        gross                  company  \
# 0      United States   55000000.0  218791811.0  Scott Rudin Productions
# 1      United States   70000000.0  218613188.0     DreamWorks Animation
# 2      United States   60000000.0  218340595.0       Paramount Pictures
# 3     United Kingdom  130000000.0  218122627.0    Twentieth Century Fox
# 4      United States   80000000.0  214040103.0   Warner Animation Group
# ...              ...          ...          ...                      ...
# 1041   United States  150000000.0  585410052.0             Warner Bros.
# 1042   United States  115000000.0  579707738.0  Pixar Animation Studios
# 1052   United States  110000000.0  574481229.0    Twentieth Century Fox
# 1053   United States   40000000.0  569651467.0           Focus Features
# 1054   United States  185000000.0  566652812.0             Warner Bros.
#
#       runtime  IMDB Rating  Month
# 0       134.0          7.8   10.0
# 1        99.0          0.0   12.0
# 2       130.0          0.0   12.0
# 3       144.0          0.0    5.0
# 4        96.0          0.0    9.0
# ...       ...          ...    ...
# 1041    101.0          0.0   12.0
# 1042     92.0          8.1   11.0
# 1052    108.0          0.0   12.0
# 1053    125.0          0.0    2.0
# 1054    118.0          0.0    3.0
#
# [838 rows x 17 columns]

# %%
#check the unique ratings
unique_titles_df["rating"].unique()
# Out:
# array(['PG-13', 'PG', 'R', 'G', 'Unknown', 'Not Rated', 'TV-PG', 'TV-MA'],
#       dtype=object)

# %%
#check if there are any null values
print(unique_titles_df.isnull().sum())
# Out:
# Title             0
# Lifetime Gross    0
# Year              0
# rating            0
# genre             0
# score             0
# votes             0
# director          0
# writer            0
# star              0
# country           0
# budget            0
# gross             0
# company           0
# runtime           0
# IMDB Rating       0
# Month             0
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#drop some columns
df2 = unique_titles_df.drop(["gross", "Title", "IMDB Rating"], axis = 1)

#label the non-numerical categories
le = LabelEncoder()
string_cat = ["genre", "director", "writer", "star", "company", "country"]
for cat in string_cat:
    df2[cat] = le.fit_transform(df2[cat]) 	

le.fit(df2['rating'])
le.classes_ = np.array(['Unknown', 'Not Rated', 'G', 'TV-PG', 'PG', 'PG-13', 'TV-MA', 'R'])
df2['rating'] = le.transform(df2['rating'])

#create correlation matrix
correlation_matrix = df2.corr()
correlation_matrix

# Set context for the plot
sns.set_context('notebook', font_scale=0.9)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the heatmap
sns.heatmap(ax=ax, data=correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm')

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Most correlated variables:
#
# 1) budget - 0.52
# 2) votes - 0.41
# 3) runtime - 0.26
# 4) score - 0.21
#
# From this, we can infer that higher budget and votes correlates to higher lifetime gross. We will keep this in mind.

# %%
#plots the distributions
p = df2.hist(figsize=(20,20))

# %% [markdown]
# Standardization Justifications:
# - Division by max keeps certain variables between 0-1
#   - votes, rating, years_since_oldest, budget, score
#
# We make it so all columns contain only numbers 0-1 representing how close they were to the max value within that column. This is because a feature like 'score' only goes up to 10 but a feature like 'budget' can be in the hundred millions. This standardization will make sure the model does not overly consider features that lend themselves to large values.
#
# - Need to be dropped:
#   - month, genre, director, star, writer, country, company

# %% [markdown]
# Some feature engineering:
# - Created new variable "years_since_oldest" that gives the number of years a film was released after the earliest film in the data and this column is divided by its max value to get values 0-1
# - Since MPA film ratings go from Unknown - R, we can consider this a maturity scale see if how mature the content of a film is affect its box office performance. Rating was manually encoded in the previous section with this scale in mind

# %%
#standarize the data for faster convergence
scalar_df = df2.drop(["director", "star", "writer", "company", "country", "Month", "genre"], axis = 1)

scalar_df["years_since_oldest"] = scalar_df["Year"] - scalar_df["Year"].min()
scalar_df = scalar_df.drop("Year", axis = 1)
#max standardization
for col in ["votes", "runtime", "rating", "years_since_oldest", 'budget', 'runtime', 'score']:
    scalar_df[col] = scalar_df[col]/scalar_df[col].max()

scalar_df = pd.DataFrame(scalar_df, columns=scalar_df.columns)

# plot the histograms
scalar_df.hist(figsize=(20, 20))
plt.show()

# %%
#create correlation matrix
correlation_matrix = scalar_df.corr()
correlation_matrix

# Set context for the plot
sns.set_context('notebook', font_scale=0.9)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the heatmap
sns.heatmap(ax=ax, data=correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm')

plt.title('Correlation Heatmap Standardized')
plt.show()

# %% [markdown]
# Visualize correlation matrix with standardized variables. We observe that 'rating' is the least correlated variable with Lifetime Gross. This makes intuitive sense since the more mature a movie a rated, the less people would be able to watch it, thus we see a negative correlation where as a movie's rating becomes more mature, Lifetime gross decreases. This is helpful in figuring out which features are more important than others; we will try to derive a more sure-proof way of determining the best features to predict lifetime gross using machine learning algorithms to determine feature importance.

# %%
X = scalar_df.drop("Lifetime Gross", axis = 1)
y = df2["Lifetime Gross"]

#training and testing set (no validation?)
X_train_fi, X_test_fi, y_train_fi, y_test_fi = train_test_split(X, y, test_size = 0.2)

X_train_fi.shape
# Out:
# (670, 6)

# %%
def feature_importance(model, X_train, y_train):
    """
    use feature importance to determine feature importance scores, and plots the result

    Parameters:
    -----------
    model : user-supplied classifier
    X_train : X train dataset
    y_train : y train dataset

    """
    #fit with model
    model.fit(X_train, y_train)

    #determines the feature scores
    feature_scores = model.feature_importances_
    
    #sorts
    indices = np.argsort(feature_scores)

    #feature names
    features = X_train.columns

    #plot
    plt.title('Feature Importance')
    plt.barh(range(len(indices)), feature_scores[indices], color='r', align='center')
    plt.xlabel('Importance')
    plt.ylabel('Feature')
    plt.yticks(range(len(indices)), [features[i] for i in indices])
    plt.show()

# %%
# create random forest classifier with n_estimators = 100
rf = RandomForestClassifier(n_estimators=100, random_state=0) 
feature_importance(rf, X_train_fi, y_train_fi)

# %% [markdown]
# The above plot confirms that the most important feature is votes, followed by runtime, budget, years_since_oldest, score, and then rating. This resulted in a slightly different result than the correlation matrix, but for the most part, it is pretty similar. Since rating has the lowest score in the correlation matrix and in the feature importance plot, it is safe to say that removing it will increase our model accuracy. However, we test it first to see if that hypothesis is true.

# %%
#dataframe without dropping rating column
rating_df = scalar_df.copy()

#dataframe with dropping rating column
scalar_df = scalar_df.drop("rating", axis=1)
#create train test split again

#train test with rating column
X = rating_df.drop("Lifetime Gross", axis = 1)
y = rating_df["Lifetime Gross"]

#training and testing set (no validation?)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

X_train.shape
rating_df
# Out:
#       Lifetime Gross    rating     score     votes    budget   runtime  \
# 0        218791811.0  0.714286  0.866667  0.180000  0.154494  0.666667
# 1        218613188.0  0.571429  0.788889  0.050833  0.196629  0.492537
# 2        218340595.0  0.714286  0.777778  0.132083  0.168539  0.646766
# 3        218237071.0  1.000000  0.800000  0.113333  0.365169  0.716418
# 4        218015531.0  0.571429  0.733333  0.015000  0.224719  0.477612
# ...              ...       ...       ...       ...       ...       ...
# 1041     585410052.0  0.714286  0.800000  0.293333  0.421348  0.502488
# 1042     579723768.0  0.285714  0.900000  0.349167  0.323034  0.457711
# 1052     574482479.0  0.571429  0.711111  0.134583  0.308989  0.537313
# 1053     569651467.0  1.000000  0.455556  0.126667  0.112360  0.621891
# 1054     568652812.0  0.714286  0.733333  0.122083  0.519663  0.587065
#
#       years_since_oldest
# 0               0.894118
# 1               0.717647
# 2               0.882353
# 3               0.800000
# 4               0.952941
# ...                  ...
# 1041            0.823529
# 1042            0.752941
# 1052            0.811765
# 1053            0.917647
# 1054            0.941176
#
# [838 rows x 7 columns]

# %% [markdown]
# ### Neural Network

# %% [markdown]
# After experimenting with various model configurations, such as changing the depth, the size, and the usage of dropout layers, we found our that the best model is the model coded below.

# %%
def construct_fnn(input_shape, output_shape):
    '''
    construct a fully connected neural network

    Parameters
    ----------
    input_shape : user-supplied input shape
    output_shape : user-supplied output shape

    Returns
    -------
    the constructed model
    '''
    FNN_model = tf.keras.models.Sequential([
    layers.Dense(64, input_shape = (input_shape,), activation='relu', kernel_initializer='he_normal'),
    layers.Dropout(0.1),
    layers.Dense(128, activation='relu', kernel_initializer='he_normal'),
    layers.Dropout(0.1),
    layers.Dense(128, activation='relu', kernel_initializer='he_normal'),
    layers.Dropout(0.3),
    layers.Dense(128, activation='relu', kernel_initializer='he_normal'),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu', kernel_initializer='he_normal'), 
    layers.Dropout(0.1),
    layers.Dense(32, activation='relu', kernel_initializer='he_normal'), 
    layers.Dropout(0.1),
    layers.Dense(output_shape)
    ],
    name = "FNN_Model",
    )
    return FNN_model

# %%
def train_model(model, training_samples, test_samples, batch_size, epochs):
    """
    trains the model, then evaluate its performance on the test samples, 
    and then return the training history.

    Parameters:
    -----------
    model : user-supplied input
    training_samples : training images and labels (train_images, train_labels).
    test_samples : test images and labels (test_images, test_labels).
    batch_size : Batch size
    
    Returns:
    -------
    history : history containing loss and accuracy metrics.
    """

    # separate images and labels
    train_images = training_samples[0]
    train_labels = training_samples[1]
    test_images = test_samples[0]
    test_labels = test_samples[1]

    
    adam = keras.optimizers.Adam(
    learning_rate=0.003,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    clipnorm=None,
    clipvalue=None,
    global_clipnorm=None,
    name="adam",
    )
    
    loss_fn = tf.keras.losses.MeanAbsolutePercentageError()
    mape = keras.metrics.MeanAbsolutePercentageError()

    # compile model
    model.compile(optimizer=adam,
              loss= loss_fn,
              metrics=[mape])
    
    # train the model and returns the test accuracy after each epoch
    history = model.fit(train_images, train_labels, epochs = epochs, batch_size = batch_size, validation_data = (test_images, test_labels), verbose = False)
    return history

# %%
#input shape is 6 because 6 features
input_shape = 6
#output shape is 1 because of one label
output_shape = 1
#call the function
FNN_model = construct_fnn(input_shape, output_shape)

# %%
# Train the model with different batch sizes and collect histories
print('FNN model with rating column\n')
print('Batch size = 16, Epochs = 75 \n')
fnn_history_8 = train_model(FNN_model, (X_train, y_train), (X_test, y_test), 16, 75)

# Evaluate the model, first value is loss, second value is MAPE
print('Evaluation results (Batch size = 16, Epochs = 75):', FNN_model.evaluate(X_test, y_test, verbose=0))

plt.plot(fnn_history_8.history["loss"], label = "training")
plt.plot(fnn_history_8.history["val_loss"], label = "validation")
plt.gca().set(xlabel = "epoch", ylabel = "MeanAbsolutePercentageError (%)")
plt.legend()
plt.show()
# Out:
# FNN model with rating column
#
# Batch size = 16, Epochs = 75
#
# Evaluation results (Batch size = 16, Epochs = 75): [26.72808265686035, 26.72808265686035]

# %% [markdown]
# The training loss is a little "ridgy", as in the plot fluctuates, but the validation loss is smoother and decreasing, and this suggests that the model is learning well and generalizing to the validation data despite some instability during training.
#
# Evaluating our model gives an mean absolute percentage error of around 25-26% consistently.

# %% [markdown]
# ### Without 'rating' column

# %% [markdown]
# Let's check if the least correlated variable 'rating', does really have an effect on the accuracy of the model.

# %%
#input shape is 5 because 5 features
input_shape = 5
#output shape is 1 because of one label
output_shape = 1

X = scalar_df.drop("Lifetime Gross", axis = 1)
y = scalar_df["Lifetime Gross"]

#training and testing set (no validation?)
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, test_size = 0.2)

X_train2.shape

print('FNN model without rating column \n')
print('Batch size = 16, Epochs = 75 \n')

FNN_model2 = construct_fnn(input_shape, output_shape)
history = train_model(FNN_model2, (X_train2, y_train2), (X_test2, y_test2), 16, 75)

# Evaluate the model, first value is loss, second value is MAPE
print('Evaluation results (Batch size = 16, Epochs = 75):', FNN_model2.evaluate(X_test2, y_test2, verbose=0))

plt.plot(history.history["loss"], label = "training")
plt.plot(history.history["val_loss"], label = "validation")
plt.gca().set(xlabel = "epoch", ylabel = "MeanAbsolutePercentageError (%)")
plt.legend()
plt.show()
# Out:
# FNN model without rating column
#
# Batch size = 16, Epochs = 75
#
# Evaluation results (Batch size = 16, Epochs = 75): [31.296714782714844, 31.296714782714844]

# %% [markdown]
# Removing the least correlated and only negatively correlated feature in 'rating' did not result in better performance. The model without the 'rating' feature averages around 2-3% greater mean absolute percentage error than when 'rating' is included.

# %% [markdown]
# ### Model Comparison

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
y_lm_pred = lm.predict(X_test)
mape = mean_absolute_percentage_error(y_test, y_lm_pred)
print("Mean Absolute Percentage Error Linear Regression:", mape)
# Out:
# Mean Absolute Percentage Error Linear Regression: 0.3432353249640543

# %%
Cval = 100
eps= 1

SVRreg = SVR(C=Cval, epsilon=eps)
SVRreg.fit(X_train,y_train)
y_SVR_pred = SVRreg.predict(X_test)
mape = mean_absolute_percentage_error(y_test, y_SVR_pred)
print("Mean Absolute Percentage Error SVR :", mape)
# Out:
# Mean Absolute Percentage Error SVR : 0.3628625829946865

# %%
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)
mape = mean_absolute_percentage_error(y_test, rf_pred)
print("Mean Absolute Percentage Error Random Forest:", mape)
# Out:
# Mean Absolute Percentage Error Random Forest: 0.30456013073910143

# %% [markdown]
# Our model does better than the sklearn models defined above.
#
# Since we are working with a Linear Regression problem in trying to predict film gross, we are happy to see that our NN can perform a bit better than the sklearn Linear Regression model

# %% [markdown]
# ### Improvements for the future

# %% [markdown]
# While our custom neural network perfomed better compared to some of the sklearn models, it is nowhere near perfect. The limitations of the model perfoming better can be because of failing to determine better features in predicting lifetime gross. It is possible that features not included in our dataset plays a big part in determining the movie success, such as the economy of when the movie was released, competition in the market, and marketing, which is difficult to quantify. The movie industry itself is difficult to predict because of that, and the specific features such as the runtime, number of votes, etc, might not be sufficient enough. Another error that could have occured that hindered our result could have been the mismatch between our features and our model. We dropped many features that seemed to not have strong correlation with lifetime gross. Because of that, we were left with only several columns, and the model might have perfomed better with more amounts of features.
